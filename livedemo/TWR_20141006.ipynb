# %% [markdown]
# # Hello Ipython notebook

# %% [markdown]
# $$ \sum_{i=1}^N a_i $$

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
import pandas as pd
# Out:
# /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /home/c3h3/.pyenv/versions/2.7.7/lib/python2.7/argparse.pyc, but /home/c3h3/.pyenv/versions/py27/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %%
import pandas.io.data as web

# %%
import datetime

# %%
start = datetime.datetime(2010, 1, 1)

# %%
end = datetime.datetime(2013, 1, 27)

# %%
f=web.DataReader("^TWII", 'yahoo', start, end)

# %%
f
# Out:
#                Open     High      Low    Close   Volume  Adj Close
# Date
# 2010-01-04  8222.42  8240.45  8143.45  8207.85  6429400    8207.85
# 2010-01-05  8277.71  8283.64  8162.54  8211.40  6762000    8211.40
# 2010-01-06  8237.10  8327.87  8216.92  8327.62  6421600    8327.62
# 2010-01-07  8344.56  8369.55  8233.59  8237.42  7133000    8237.42
# 2010-01-08  8266.87  8290.66  8178.93  8280.90  5764400    8280.90
# 2010-01-11  8291.52  8357.90  8281.72  8323.82  5857000    8323.82
# 2010-01-12  8343.73  8356.97  8262.58  8309.37  5246000    8309.37
# 2010-01-13  8229.25  8257.83  8194.81  8196.56  4925600    8196.56
# 2010-01-14  8245.86  8313.94  8237.67  8289.98  4837200    8289.98
# 2010-01-15  8340.60  8380.23  8325.82  8356.89  5643400    8356.89
# 2010-01-18  8290.38  8367.65  8290.38  8337.82  5100400    8337.82
# 2010-01-19  8387.66  8395.39  8227.30  8249.00  5582400    8249.00
# 2010-01-20  8309.19  8309.19  8191.44  8220.93  5009800    8220.93
# ...

# %%
f["High"] - f["Low"]
# Out:
# Date
# 2010-01-04     97.00
# 2010-01-05    121.10
# 2010-01-06    110.95
# 2010-01-07    135.96
# 2010-01-08    111.73
# 2010-01-11     76.18
# 2010-01-12     94.39
# 2010-01-13     63.02
# 2010-01-14     76.27
# 2010-01-15     54.41
# 2010-01-18     77.27
# 2010-01-19    168.09
# 2010-01-20    117.75
# 2010-01-21    100.66
# 2010-01-22    103.10
# ...
# 2013-01-07     71.58
# 2013-01-08     58.82
# 2013-01-09     60.74
# 2013-01-10     64.97
# 2013-01-11     43.67
# 2013-01-14     92.65
# 2013-01-15     79.12
# 2013-01-16     68.75
# 2013-01-17    171.70
# 2013-01-18     56.76
# 2013-01-21     65.19
# 2013-01-22     60.22
# 2013-01-23     43.10
# 2013-01-24     71.06
# 2013-01-25     67.11
# Length: 762

# %%
(f["High"] - f["Low"]).plot()
