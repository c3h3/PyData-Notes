# %%
# %matplotlib inline

# %%
import matplotlib.pylab as pylab
import matplotlib.cm as cm
pylab.rcParams['figure.figsize'] = 16, 12
pylab.ion()

# %%
print(__doc__)
from time import time

import numpy as np
import pylab as pl
from matplotlib import offsetbox
# Out:
# Automatically created module for IPython interactive environment

# %%
from sklearn import (manifold, datasets, decomposition, ensemble, lda,
                     random_projection)

digits = datasets.load_digits(n_class=6)
X = digits.data
y = digits.target
n_samples, n_features = X.shape
n_neighbors = 30

# %%
pylab.imshow(X[0,:].reshape(8,8),cmap=cm.gray)

# %%
row_imgs = 5
col_imgs = 5

fig, axe = pylab.subplots(row_imgs,col_imgs)

img_idx = 0
for ax in axe.flatten():
    ax.imshow(X[y == 4,:][img_idx,:].reshape(8,8),cmap=cm.gray)
    img_idx = img_idx + 1

# %%
# Out:
# 30

# %%
pylab.imshow(np.c_[X[y == 0,:][:40,:].T,X[y == 1,:][:40,:].T],cmap=cm.gray)

# %%
pylab.imshow(np.c_[X[y == 2,:][:40,:].T,X[y == 5,:][:40,:].T],cmap=cm.gray)

# %%
pylab.imshow(np.c_[X[y == 4,:][:40,:].T,X[y == 1,:][:40,:].T],cmap=cm.gray)

# %%
pylab.imshow(X[y == 1,:].T,cmap=cm.gray)
