# %% [markdown]
# # Reference:
#
# - ## [sklearn-classification] http://scikit-learn.org/stable/auto_examples/plot_digits_classification.html
#
# - ## [Kaggle] http://www.kaggle.com/c/digit-recognizer/
#
# - ## https://github.com/nigma/pywt/blob/master/demo/wp_2d.py

# %%
from sklearn import datasets, svm, metrics

# %%
digits = datasets.load_digits()

# %%
digits
# Out:
# {'DESCR': " Optical Recognition of Handwritten Digits Data Set\n\nNotes\n-----\nData Set Characteristics:\n    :Number of Instances: 5620\n    :Number of Attributes: 64\n    :Attribute Information: 8x8 image of integer pixels in the range 0..16.\n    :Missing Attribute Values: None\n    :Creator: E. Alpaydin (alpaydin '@' boun.edu.tr)\n    :Date: July; 1998\n\nThis is a copy of the test set of the UCI ML hand-written digits datasets\nhttp://archive.ics.uci.edu/ml/datasets/Optical+Recognition+of+Handwritten+Digits\n\nThe data set contains images of hand-written digits: 10 classes where\neach class refers to a digit.\n\nPreprocessing programs made available by NIST were used to extract\nnormalized bitmaps of handwritten digits from a preprinted form. From a\ntotal of 43 people, 30 contributed to the training set and different 13\nto the test set. 32x32 bitmaps are divided into nonoverlapping blocks of\n4x4 and the number of on pixels are counted in each block. This generates\nan input 
# ...

# %%
print digits["target"].shape
print digits["images"].shape
print digits["data"].shape
# Out:
# (1797,)
# (1797, 8, 8)
# (1797, 64)

# %%
# %matplotlib inline

# %%
import matplotlib.pylab as pylab
import matplotlib.cm as cm
pylab.rcParams['figure.figsize'] = 16, 12
pylab.ion()

# %%
print(__doc__)
from time import time

import numpy as np
import pylab as pl
from matplotlib import offsetbox
# Out:
# Automatically created module for IPython interactive environment

# %%
from sklearn import (manifold, datasets, decomposition, ensemble, lda,
                     random_projection)

digits = datasets.load_digits(n_class=6)
X = digits.data
y = digits.target
n_samples, n_features = X.shape
n_neighbors = 30

# %%
pylab.imshow(X[0,:].reshape(8,8).T,cmap=cm.gray)

# %%
row_imgs = 5
col_imgs = 5

fig, axe = pylab.subplots(row_imgs,col_imgs)

img_idx = 0
for ax in axe.flatten():
    ax.imshow(X[y == 4,:][img_idx,:].reshape(8,8).T,cmap=cm.gray)
    img_idx = img_idx + 1

# %%
# Out:
# 30

# %%
pylab.imshow(np.c_[X[y == 0,:][:40,:].T,X[y == 1,:][:40,:].T],cmap=cm.gray)

# %%
pylab.imshow(np.c_[X[y == 2,:][:40,:].T,X[y == 5,:][:40,:].T],cmap=cm.gray)

# %%
pylab.imshow(np.c_[X[y == 4,:][:40,:].T,X[y == 1,:][:40,:].T],cmap=cm.gray)

# %%
pylab.imshow(X[y == 1,:].T,cmap=cm.gray)
